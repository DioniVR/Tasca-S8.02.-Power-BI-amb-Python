# %% [markdown]
# Sprint 8.2

# %% [markdown]
# Situaciones que me he encontrado en casi todas las gráficas:
#
# - Los datos númericos se han importado mal. He tenido que hacer un cambio de puntos por comas para que las aceptara.
# - A veces cogía las datos como si fueran texto en lugar de números. He mirado que todos los campos tengan la variable de acuerdo al tipo de datos que contiene.
# - Powerbi nombra los dataframe como dataset. HE tenido que cambiar todos los script para renombrar los dataframes como dataset.
# - Powerbi elimina los datos duplicados, en varias gráficas he tenido que marcar el campo ID para que graficara bien.
# - Las diferentes tablas del dataframe no se han relacionado. Las he tenido que relacionar yo manualmente.
# -  He tenido que importar las librerías de matplotlib y seaborn en todos los ejercicios
# - Si no pongo el plt.show() los gráficos no se ven en powerbi.
#
# Para no repetir estos problemas descritos en cada gráfico, en cada ejercicio sólo voy a poner los problemas específicas que he encontrado con ese gráfico.

# %% [markdown]
# Nivel 1  - Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas en el ejercio 1 - Nivel 1
#
# He tenido que marcar el campo ID para que grafique bien.
# He tenido que poner el título a fontsize = 30 para que se vea más grande.

# %% [markdown]
# Nivel 1  - Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 2 - Nivel 1
#
# En este gráfico sólo he tenido los problemas generales descritos al principio de esta página.

# %% [markdown]
# Nivel 1  - Ejercicio 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 3 - Nivel 1
#
# En este gráfico sólo he tenido los problemas generales descritos al principio de esta página.

# %% [markdown]
# Nivel 1  - Ejercicio 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 4 - Nivel 1
#
# - He tenido que cambiar el fontsize del título a 16 para que se viera bien.
# - He en script de python, la variable X se llamaba "Timestamp" y la he tenido que renombrar a "Año para que funcione.
# - En la variable amount me ponía no resumir. He tenido que cambiar para que me haga la suma del Amount.
# - LA función barplot por defecto calcula la media. Para que calcule la suma, hay que poner estimator=np.sum que es una función de numpy. Para que esto funcione he tenido que poner el "import numpy as np"

# %% [markdown]
# Nivel 1  - Ejercicio 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 5 - Nivel 1
#
#
# - Como en la función del barplot aparecía una función de numpy, en estimor, he tenido que importar la librería numpy ( import numpy as np)
# - En la variable amount he tenido que poner suma para que me funcione.
# - He tenido  que quitar el plt.figure(figsize = (10,8)) para que en powerbi se vea mejor el gráfico. Así se ve más alargado el gráfico para visualizarlo en este pantallazo de arriba.

# %% [markdown]
# Nivel 1  - Ejercicio 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Problemas con el ejercicio 6 - Nivel 1

- He tenido que crear una función range mediante agregar una columna condicional en powerbi para clasificar los precio de los productos entre cheap, medium y expensive.
- El gráfico es el mismo que el que me sale en power

# %% [markdown]
# Nivel 1  - Ejercicio 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Problemas con el ejercicio 7 - Nivel 1

- He tenido que crear una columna calculada en powerbi para calcular la edad  llamada "age".
- He tenido que calcular una columna calculada en powerbi, para hacer un rango de edades llamada "age_range".
- He tenido que reorganizar el orden el orden de los valores en powerbi para el orden de los valores en powerbi sea el mismo que en python.
- He tenido que cambiar el fontsize  a 10 para que el título se vea bien.
- He renombrado Id a User y product_ID a units sold, pero no he conseguido que se cambien los nombres en el gráfico de powerbi.
- HE cambiado el product_id a recuento para que me haga bien el gráfico
- He tenido que marcar el Id de df_user para que powerbi no me eliminara duplicados.

No he podido resolver.

- He renombrado la variable product_id para que ponga "Units purchased" pero power bi no hace el cambio en el gráfico.

# %%
Nivel 2  - Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 1 - Nivel 2
#
# - Para que me calculara las correlaciones, he tenido que importar la librería pandas y ejecutar la función cor.
# - Para que el título no se viera tan grande, he reducido el fontsize a 15.
# - PAra que el orden de los valores coincida con el gráfico de python, he tenido que poner las variables en el siguiente orden: Amount, weigth, price, Lat, Longitude

# %% [markdown]
# Nivel 2  - Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 2 - Nivel 2
#
# En este gráfico sólo he tenido los problemas generales descritos al principio de esta página.

# %% [markdown]
# Nivel 3  - Ejercicio 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problemas con el ejercicio 1 - Nivel 3
#
# En este gráfico sólo he tenido los problemas generales descritos al principio de esta página.

# %% [markdown]
# Nivel 3  - Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Problemas con el ejercicio 2 - Nivel 3

- En el script de python usa en la variable hue "Timestamp" pero powerbi he tenido que poner "Año".
- Los colores son diferentes para los años.  En python el 2021 en azul y el  2022 en negro. En powerbi es al revés.
- He tenido que poner un filtro para quedarme con los tres productos seleccionados ("Direwolf Stannis","skywalker ewok","riverlands north")
- Los productos no me aparecen ordenados en el mismo orden que en el gráfico de python.

# %%
---
